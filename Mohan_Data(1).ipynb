# %%
# NumPy for numerical computing
import numpy as np

# Pandas for DataFrames
import pandas as pd
pd.set_option('display.max_columns', 100)

# Matplotlib for visualization
from matplotlib import pyplot as plt
# display plots in the notebook
# %matplotlib inline 

# Seaborn for easier visualization
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/bkumar66/Desktop/MergedData.csv")

# %%
df.shape
# Out:
# (558211, 42)

# %%
df.head()
# Out:
#    Provider      BeneID    ClaimID  InscClaimAmtReimbursed AttendingPhysician  \
# 0  PRV51001   BENE86784  CLM119495                      10          PHY350459
# 1  PRV51001  BENE130029  CLM262535                      90          PHY409648
# 2  PRV51001  BENE102690   CLM49733                   42000          PHY383193
# 3  PRV51001   BENE38773   CLM52334                   12000          PHY346762
# 4  PRV51001   BENE32715  CLM272936                     500          PHY318842
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0          PHY330576      PHY350459               2767              Other
# 1          PHY330576      PHY409648              56989              Other
# 2          PHY378091      PHY389113               4241              42731
# 3          PHY330576      PHY412132               0388               5849
# 4          PHY392882      PHY412132              78964               V442
#
# ...

# %%
df.columns
# Out:
# Index(['Provider', 'BeneID', 'ClaimID', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'DeductibleAmtPaid', 'ClmAdmitDiagnosisCode',
#        'DaysInHospital', 'ClaimTenure', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
#        'ChronicCond_Depression', 'ChronicCond_Diabetes',
#        'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
#        'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke',
#        'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
# ...

# %%
df.dtypes
# Out:
# Provider                           object
# BeneID                             object
# ClaimID                            object
# InscClaimAmtReimbursed              int64
# AttendingPhysician                 object
# OperatingPhysician                 object
# OtherPhysician                     object
# ClmDiagnosisCode_1                 object
# ClmDiagnosisCode_2                 object
# ClmDiagnosisCode_3                 object
# ClmDiagnosisCode_4                 object
# ClmDiagnosisCode_5                 object
# ClmDiagnosisCode_6                 object
# ClmDiagnosisCode_7                 object
# DeductibleAmtPaid                   int64
# ClmAdmitDiagnosisCode              object
# DaysInHospital                      int64
# ClaimTenure                         int64
# Gender                              int64
# Race                                int64
# RenalDiseaseIndicator              object
# State                               int64
# ...

# %%
#Converting Numerics to categorical Varibles
df['Gender']=df['Gender'].astype('object')
df['ChronicCond_Alzheimer']=df['ChronicCond_Alzheimer'].astype('object')
df['ChronicCond_Heartfailure']=df['ChronicCond_Heartfailure'].astype('object')
df['ChronicCond_KidneyDisease']=df['ChronicCond_KidneyDisease'].astype('object')
df['State']=df['State'].astype('object')
df['County']=df['County'].astype('object')
df['ChronicCond_Cancer']=df['ChronicCond_Cancer'].astype('object')
df['ChronicCond_ObstrPulmonary']=df['ChronicCond_ObstrPulmonary'].astype('object')
df['ChronicCond_Depression']=df['ChronicCond_Depression'].astype('object')
df['ChronicCond_Diabetes']=df['ChronicCond_Diabetes'].astype('object')
df['ChronicCond_IschemicHeart']=df['ChronicCond_IschemicHeart'].astype('object')
df['ChronicCond_Osteoporasis']=df['ChronicCond_Osteoporasis'].astype('object')
df['ChronicCond_rheumatoidarthritis']=df['ChronicCond_rheumatoidarthritis'].astype('object')
df['ChronicCond_stroke']=df['ChronicCond_stroke'].astype('object')
df['Race']=df['Race'].astype('object')

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Provider                           object
# BeneID                             object
# ClaimID                            object
# AttendingPhysician                 object
# OperatingPhysician                 object
# OtherPhysician                     object
# ClmDiagnosisCode_1                 object
# ClmDiagnosisCode_2                 object
# ClmDiagnosisCode_3                 object
# ClmDiagnosisCode_4                 object
# ClmDiagnosisCode_5                 object
# ClmDiagnosisCode_6                 object
# ClmDiagnosisCode_7                 object
# ClmAdmitDiagnosisCode              object
# Gender                             object
# RenalDiseaseIndicator              object
# State                              object
# County                             object
# ChronicCond_Alzheimer              object
# ChronicCond_Heartfailure           object
# ChronicCond_KidneyDisease          object
# ChronicCond_Cancer                 object
# ...

# %%
df.dtypes[df.dtypes!='object']
# Out:
# InscClaimAmtReimbursed      int64
# DeductibleAmtPaid           int64
# DaysInHospital              int64
# ClaimTenure                 int64
# NoOfMonths_PartACov         int64
# NoOfMonths_PartBCov         int64
# IPAnnualReimbursementAmt    int64
# IPAnnualDeductibleAmt       int64
# OPAnnualReimbursementAmt    int64
# OPAnnualDeductibleAmt       int64
# Age                         int64
# dtype: object

# %%
#Count of the numeric and categorical
print("Numeric Variables : "+str(df.dtypes[df.dtypes!='object'].count()))
print("Categorical Varibales : "+str(df.dtypes[df.dtypes=='object'].count()))
# Out:
# Numeric Variables : 11
# Categorical Varibales : 31

# %%
#No of NA's
df.isna().sum()
# Out:
# Provider                           0
# BeneID                             0
# ClaimID                            0
# InscClaimAmtReimbursed             0
# AttendingPhysician                 0
# OperatingPhysician                 0
# OtherPhysician                     0
# ClmDiagnosisCode_1                 0
# ClmDiagnosisCode_2                 0
# ClmDiagnosisCode_3                 0
# ClmDiagnosisCode_4                 0
# ClmDiagnosisCode_5                 0
# ClmDiagnosisCode_6                 0
# ClmDiagnosisCode_7                 0
# DeductibleAmtPaid                  0
# ClmAdmitDiagnosisCode              0
# DaysInHospital                     0
# ClaimTenure                        0
# Gender                             0
# Race                               0
# RenalDiseaseIndicator              0
# State                              0
# County                             0
# NoOfMonths_PartACov                0
# NoOfMonths_PartBCov                0
# ...

# %%
df.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid  DaysInHospital  \
# count           558211.000000      558211.000000   558211.000000
# mean               997.012133          78.294788        0.410762
# std               3821.534891         273.814128        2.112693
# min                  0.000000           0.000000        0.000000
# 25%                 40.000000           0.000000        0.000000
# 50%                 80.000000           0.000000        0.000000
# 75%                300.000000           0.000000        0.000000
# max             125000.000000        1068.000000       35.000000
#
#          ClaimTenure           Race  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# count  558211.000000  558211.000000        558211.000000         558211.00000
# mean        1.727940       1.255011            11.931472             11.93877
# std         4.904984       0.717437             0.889712              0.78590
# ...

# %%
df.hist(figsize=(20,14),xrot=0)
plt.show()

# %%
for colname in df.dtypes[df.dtypes!='object'].index:
    print(colname)
    print(df[colname].describe())
    df[colname].hist(figsize=(6,6),xrot=45,bins=30)
    plt.show()
# Out:
# InscClaimAmtReimbursed
# count    558211.000000
# mean        997.012133
# std        3821.534891
# min           0.000000
# 25%          40.000000
# 50%          80.000000
# 75%         300.000000
# max      125000.000000
# Name: InscClaimAmtReimbursed, dtype: float64
# DeductibleAmtPaid
# count    558211.000000
# mean         78.294788
# std         273.814128
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        1068.000000
# Name: DeductibleAmtPaid, dtype: float64
# DaysInHospital
# count    558211.000000
# mean          0.410762
# std           2.112693
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          35.000000
# Name: DaysInHospital, dtype: float64
# ClaimTenure
# count    558211.000000
# mean          1.727940
# std           4.904984
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# ...

# %%
#Categorical variable Summary
df.describe(include='object')
# Out:
#         Provider     BeneID    ClaimID AttendingPhysician OperatingPhysician  \
# count     558211     558211     558211             558211             558211
# unique      5410     138556     558211              82063              35315
# top     PRV51459  BENE59303  CLM706297          PHY330576          PHY330576
# freq        8240         29          1               4042             444188
#
#        OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# count          558211             558211             558211
# unique          46457              10451               5301
# top         PHY412132               4019              Other
# freq           359722              13886             195606
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# count              558211             558211             558211
# unique               4757               4360               3971
# top                 Other              Other              Other
# ...

# %%
#Each categorical High level frequency

for variable in df.dtypes[df.dtypes=='object'].index:
    print("************")
    print(variable)
    print(df[variable].value_counts().sort_values(ascending=False))
    print("************")
# Out:
# ************
# Provider
# PRV51459    8240
# PRV53797    4739
# PRV51574    4444
# PRV53918    3588
# PRV54895    3436
# PRV55215    3393
# PRV52064    2844
# PRV56011    2833
# PRV55004    2399
# PRV57306    2315
# PRV56560    2313
# PRV52030    2275
# PRV52649    2156
# PRV54772    2115
# PRV52628    2098
# PRV51369    2083
# PRV51347    2067
# PRV55039    2058
# PRV57103    2049
# PRV52019    1961
# PRV51480    1924
# PRV55462    1907
# PRV55467    1896
# PRV54742    1892
# PRV52041    1885
# PRV54837    1843
# PRV54966    1796
# PRV51836    1794
# PRV56689    1794
# PRV57172    1760
#             ...
# PRV56029       1
# PRV51423       1
# PRV54549       1
# PRV51239       1
# PRV51136       1
# PRV53506       1
# PRV56582       1
# PRV52957       1
# PRV56902       1
# PRV56988       1
# PRV55400       1
# PRV55427       1
# PRV54449       1
# PRV52763       1
# PRV51918       1
# PRV57399       1
# PRV56091       1
# PRV55778       1
# PRV54006       1
# PRV54199       1
# ...

# %%
#Outliers or Boxplot
for variable in df.dtypes[df.dtypes!='object'].index:
    sns.violinplot(y='PotentialFraud', x=variable, data=df)
    plt.show()

# %%
print(df.InscClaimAmtReimbursed.describe())
print(df.groupby('PotentialFraud').InscClaimAmtReimbursed.describe())
# Out:
# count    558211.000000
# mean        997.012133
# std        3821.534891
# min           0.000000
# 25%          40.000000
# 50%          80.000000
# 75%         300.000000
# max      125000.000000
# Name: InscClaimAmtReimbursed, dtype: float64
#                    count         mean          std  min   25%   50%    75%  \
# PotentialFraud
# No              345415.0   755.213352  3056.460166  0.0  40.0  80.0  300.0
# Yes             212796.0  1389.505066  4785.074685  0.0  40.0  90.0  400.0
#
#                      max
# PotentialFraud
# No              125000.0
# Yes             125000.0

# %%
#Correlations
correlatons=df.corr()

#visulaise the HeatMap
plt.figure(figsize=(12,8))

# Plot heatmap of annotated correlations
sns.heatmap(correlatons * 100, annot=True, fmt='.0f')

# Change color scheme
sns.set_style("white")

# %%
df.columns
# Out:
# Index(['Provider', 'BeneID', 'ClaimID', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'DeductibleAmtPaid', 'ClmAdmitDiagnosisCode',
#        'DaysInHospital', 'ClaimTenure', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
#        'ChronicCond_Depression', 'ChronicCond_Diabetes',
#        'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
#        'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke',
#        'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
# ...

# %%
#Each state unique provider Data
df1=df.groupby('State').Provider.nunique()
df1.plot(kind='bar',figsize=(22,9))

# %%
df_ClaimYes=df[df.PotentialFraud=='Yes'].groupby('State').Provider.count()
df_ClaimNo=df[df.PotentialFraud=='No'].groupby('State').Provider.count()
df_ClaimYes.plot(kind='bar',figsize=(22,9))
plt.show()
df_ClaimNo.plot(kind='bar',figsize=(22,9))
plt.show()
