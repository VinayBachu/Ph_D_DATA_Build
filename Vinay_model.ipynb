# %%
# NumPy for numerical computing
import numpy as np

# Pandas for DataFrames
import pandas as pd
pd.set_option('display.max_columns', 100)

# Matplotlib for visualization
from matplotlib import pyplot as plt
# display plots in the notebook
# %matplotlib inline 

# Seaborn for easier visualization
import seaborn as sns

# %% [markdown]
# PROVIDER DATA:
# ===============

# %%
df=pd.read_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Train-1542865627584.csv')

# %%
df.shape
# Out:
# (5410, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5410 entries, 0 to 5409
# Data columns (total 2 columns):
# Provider          5410 non-null object
# PotentialFraud    5410 non-null object
# dtypes: object(2)
# memory usage: 84.6+ KB

# %%
df.nunique()
# Out:
# Provider          5410
# PotentialFraud       2
# dtype: int64

# %% [markdown]
# Conclusion : There are only 5410 Unique providers. We have to find the providrs which are Fraud

# %%
df.PotentialFraud.value_counts().plot(kind='bar')
print(df.PotentialFraud.value_counts())
# Out:
# No     4904
# Yes     506
# Name: PotentialFraud, dtype: int64

# %% [markdown]
# Providers with Fraud data is very less compared to the  not fraud providers

# %%
df[df['PotentialFraud']=='Yes'].head()#Providers which are Fraud
# Out:
#     Provider PotentialFraud
# 1   PRV51003            Yes
# 3   PRV51005            Yes
# 13  PRV51021            Yes
# 25  PRV51037            Yes
# 37  PRV51052            Yes

# %%
# verification for process
print("Total number of Providers",4904+506)   # Total Number of Unique Providers
print("Non_ Fraud---------------",4904/5410)  # non Fraud
print("Fraud--------------------",506/4904)
# Out:
# Total number of Providers 5410
# Non_ Fraud--------------- 0.9064695009242144
# Fraud-------------------- 0.10318107667210441

# %% [markdown]
# 90% data containes not fraud data and 10% data with Fraud Data

# %% [markdown]
# Exploring the Benficiary data to Understand
# ====================================

# %%
benf=pd.read_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Train_Beneficiarydata-1542865627584.csv')

# %%
benf.shape
# Out:
# (138556, 25)

# %%
benf.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
# ...

# %%
benf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138556 entries, 0 to 138555
# Data columns (total 25 columns):
# BeneID                             138556 non-null object
# DOB                                138556 non-null object
# DOD                                1421 non-null object
# Gender                             138556 non-null int64
# Race                               138556 non-null int64
# RenalDiseaseIndicator              138556 non-null object
# State                              138556 non-null int64
# County                             138556 non-null int64
# NoOfMonths_PartACov                138556 non-null int64
# NoOfMonths_PartBCov                138556 non-null int64
# ChronicCond_Alzheimer              138556 non-null int64
# ChronicCond_Heartfailure           138556 non-null int64
# ChronicCond_KidneyDisease          138556 non-null int64
# ChronicCond_Cancer                 138556 non-null int64
# ...

# %% [markdown]
# DOD vailable for only 1421 beneficiaries only

# %%
benf.nunique()
# Out:
# BeneID                             138556
# DOB                                   900
# DOD                                    11
# Gender                                  2
# Race                                    4
# RenalDiseaseIndicator                   2
# State                                  52
# County                                314
# NoOfMonths_PartACov                    13
# NoOfMonths_PartBCov                    13
# ChronicCond_Alzheimer                   2
# ChronicCond_Heartfailure                2
# ChronicCond_KidneyDisease               2
# ChronicCond_Cancer                      2
# ChronicCond_ObstrPulmonary              2
# ChronicCond_Depression                  2
# ChronicCond_Diabetes                    2
# ChronicCond_IschemicHeart               2
# ChronicCond_Osteoporasis                2
# ChronicCond_rheumatoidarthritis         2
# ChronicCond_stroke                      2
# IPAnnualReimbursementAmt             3004
# ...

# %%
benf.columns
# Out:
# Index(['BeneID', 'DOB', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt'],
#       dtype='object')

# %%
benf.describe()
# Out:
#               Gender           Race          State         County  \
# count  138556.000000  138556.000000  138556.000000  138556.000000
# mean        1.570932       1.254511      25.666734     374.424745
# std         0.494945       0.717007      15.223443     266.277581
# min         1.000000       1.000000       1.000000       0.000000
# 25%         1.000000       1.000000      11.000000     141.000000
# 50%         2.000000       1.000000      25.000000     340.000000
# 75%         2.000000       1.000000      39.000000     570.000000
# max         2.000000       5.000000      54.000000     999.000000
#
#        NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# count        138556.000000        138556.000000          138556.000000
# mean             11.907727            11.910145               1.667817
# std               1.032332             0.936893               0.470998
# min               0.000000             0.000000               1.000000
# ...

# %%
benf.describe(include='object')
# Out:
#            BeneID         DOB         DOD RenalDiseaseIndicator
# count      138556      138556        1421                138556
# unique     138556         900          11                     2
# top     BENE58250  1939-10-01  2009-12-01                     0
# freq            1         540         182                118978

# %%
benf.dtypes
# Out:
# BeneID                             object
# DOB                                object
# DOD                                object
# Gender                              int64
# Race                                int64
# RenalDiseaseIndicator              object
# State                               int64
# County                              int64
# NoOfMonths_PartACov                 int64
# NoOfMonths_PartBCov                 int64
# ChronicCond_Alzheimer               int64
# ChronicCond_Heartfailure            int64
# ChronicCond_KidneyDisease           int64
# ChronicCond_Cancer                  int64
# ChronicCond_ObstrPulmonary          int64
# ChronicCond_Depression              int64
# ChronicCond_Diabetes                int64
# ChronicCond_IschemicHeart           int64
# ChronicCond_Osteoporasis            int64
# ChronicCond_rheumatoidarthritis     int64
# ChronicCond_stroke                  int64
# IPAnnualReimbursementAmt            int64
# ...

# %% [markdown]
# We have to get the age of the beneficiary by using the DOB of the each beneficiary

# %%
benf['DOB'].head()
# Out:
# 0    1943-01-01
# 1    1936-09-01
# 2    1936-08-01
# 3    1922-07-01
# 4    1935-09-01
# Name: DOB, dtype: object

# %%
benf['DOB'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Datatypeof the data is Object we have to convert the object format

# %%
import pandas as pd
from datetime import datetime
from datetime import date

# %%
today=date.today()
print(today) #Checking
# Out:
# 2018-12-18

# %%
#Converting to Datetime
today = date.today()
benf['DOB'] = pd.to_datetime(benf['DOB'])

# Added one Extra date column to calculate age
benf['today'] = datetime.today()

# %%
benf.dtypes
#NowDOB is converted as Date format . Now we can calculate the Age of the each beneficiary
# Out:
# BeneID                                     object
# DOB                                datetime64[ns]
# DOD                                        object
# Gender                                      int64
# Race                                        int64
# RenalDiseaseIndicator                      object
# State                                       int64
# County                                      int64
# NoOfMonths_PartACov                         int64
# NoOfMonths_PartBCov                         int64
# ChronicCond_Alzheimer                       int64
# ChronicCond_Heartfailure                    int64
# ChronicCond_KidneyDisease                   int64
# ChronicCond_Cancer                          int64
# ChronicCond_ObstrPulmonary                  int64
# ChronicCond_Depression                      int64
# ChronicCond_Diabetes                        int64
# ChronicCond_IschemicHeart                   int64
# ChronicCond_Osteoporasis                    int64
# ...

# %% [markdown]
# Write in Notes
# ============

# %%
# Function for calculating and seperating years
from dateutil import relativedelta

def intck_month(row):
    start, end = row['DOB'], row['today']
    rd = relativedelta.relativedelta( pd.to_datetime( end ), pd.to_datetime( start ) )
    return rd.years

# %%
benf['Age']=benf[['DOB','today']].apply(intck_month, axis = 1)

# %%
benf['Age'].head(10) #this age is not correct for all as few people are died
# Out:
# 0    75
# 1    82
# 2    82
# 3    96
# 4    83
# 5    42
# 6    78
# 7    84
# 8    89
# 9    82
# Name: Age, dtype: int64

# %%
#Now we will deal with dead beneficiary

# %%
def intck_month1(row):
    start, end = row['DOB'], row['DOD']
    rd = relativedelta.relativedelta( pd.to_datetime( end ), pd.to_datetime( start ) )
    return rd.years

# %%
benf['Age']=benf[benf['DOD'].notnull()][['DOB','DOD']].apply(intck_month1, axis = 1)
benf['Age']=benf[benf['DOD'].isnull()][['DOB','today']].apply(intck_month, axis = 1)

# %%
benf.head(20) #If you do this u ll not get the correct results. SOlution fill the NA values of the df['DOD']
# Out:
#        BeneID        DOB         DOD  Gender  Race RenalDiseaseIndicator  \
# 0   BENE11001 1943-01-01         NaN       1     1                     0
# 1   BENE11002 1936-09-01         NaN       2     1                     0
# 2   BENE11003 1936-08-01         NaN       1     1                     0
# 3   BENE11004 1922-07-01         NaN       1     1                     0
# 4   BENE11005 1935-09-01         NaN       1     1                     0
# 5   BENE11006 1976-09-01         NaN       2     1                     0
# 6   BENE11007 1940-09-01  2009-12-01       1     2                     0
# 7   BENE11008 1934-02-01         NaN       2     1                     0
# 8   BENE11009 1929-06-01         NaN       1     1                     Y
# 9   BENE11010 1936-07-01         NaN       2     1                     0
# 10  BENE11011 1914-03-01         NaN       2     2                     0
# 11  BENE11012 1934-05-01         NaN       1     1                     0
# ...

# %%
benf['DOD'].fillna(datetime.today(),inplace=True)

# %%
benf.head(10) #now apply our function
# Out:
#       BeneID        DOB                         DOD  Gender  Race  \
# 0  BENE11001 1943-01-01  2018-12-18 12:46:26.336420       1     1
# 1  BENE11002 1936-09-01  2018-12-18 12:46:26.336420       2     1
# 2  BENE11003 1936-08-01  2018-12-18 12:46:26.336420       1     1
# 3  BENE11004 1922-07-01  2018-12-18 12:46:26.336420       1     1
# 4  BENE11005 1935-09-01  2018-12-18 12:46:26.336420       1     1
# 5  BENE11006 1976-09-01  2018-12-18 12:46:26.336420       2     1
# 6  BENE11007 1940-09-01                  2009-12-01       1     2
# 7  BENE11008 1934-02-01  2018-12-18 12:46:26.336420       2     1
# 8  BENE11009 1929-06-01  2018-12-18 12:46:26.336420       1     1
# 9  BENE11010 1936-07-01  2018-12-18 12:46:26.336420       2     1
#
#   RenalDiseaseIndicator  State  County  NoOfMonths_PartACov  \
# 0                     0     39     230                   12
# 1                     0     39     280                   12
# ...

# %%
#Change the function code

from dateutil import relativedelta

def intck_month(row):
    start, end = row['DOB'], row['DOD']
    rd = relativedelta.relativedelta( pd.to_datetime( end ), pd.to_datetime( start ) )
    return rd.years

# %%
benf['Age']=benf[['DOB','DOD']].apply(intck_month, axis = 1)

# %%
benf.head(10)#now able to see the all ages
# Out:
#       BeneID        DOB                         DOD  Gender  Race  \
# 0  BENE11001 1943-01-01  2018-12-18 12:46:26.336420       1     1
# 1  BENE11002 1936-09-01  2018-12-18 12:46:26.336420       2     1
# 2  BENE11003 1936-08-01  2018-12-18 12:46:26.336420       1     1
# 3  BENE11004 1922-07-01  2018-12-18 12:46:26.336420       1     1
# 4  BENE11005 1935-09-01  2018-12-18 12:46:26.336420       1     1
# 5  BENE11006 1976-09-01  2018-12-18 12:46:26.336420       2     1
# 6  BENE11007 1940-09-01                  2009-12-01       1     2
# 7  BENE11008 1934-02-01  2018-12-18 12:46:26.336420       2     1
# 8  BENE11009 1929-06-01  2018-12-18 12:46:26.336420       1     1
# 9  BENE11010 1936-07-01  2018-12-18 12:46:26.336420       2     1
#
#   RenalDiseaseIndicator  State  County  NoOfMonths_PartACov  \
# 0                     0     39     230                   12
# 1                     0     39     280                   12
# ...

# %%
del benf['Age1']
del benf['Age3']

# %%
del benf['DOB']
del benf['DOD']

# %%
benf.head(8)#Now able to see the age of the each beneficiary
# Out:
#       BeneID  Gender  Race RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                     0     39     230
# 1  BENE11002       2     1                     0     39     280
# 2  BENE11003       1     1                     0     52     590
# 3  BENE11004       1     1                     0     39     270
# 4  BENE11005       1     1                     0     24     680
# 5  BENE11006       2     1                     0     23     810
# 6  BENE11007       1     2                     0     45     610
# 7  BENE11008       2     1                     0     15     140
#
#    NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                   12                   12                      1
# 1                   12                   12                      2
# 2                   12                   12                      1
# 3                   12                   12                      1
# ...

# %% [markdown]
# Exploring about the inpatient data
# ============================

# %%
ipdata=pd.read_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Train_Inpatientdata-1542865627584.csv')

# %%
ipdata.shape
# Out:
# (40474, 30)

# %%
ipdata.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
ipdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Data columns (total 30 columns):
# BeneID                    40474 non-null object
# ClaimID                   40474 non-null object
# ClaimStartDt              40474 non-null object
# ClaimEndDt                40474 non-null object
# Provider                  40474 non-null object
# InscClaimAmtReimbursed    40474 non-null int64
# AttendingPhysician        40362 non-null object
# OperatingPhysician        23830 non-null object
# OtherPhysician            4690 non-null object
# AdmissionDt               40474 non-null object
# ClmAdmitDiagnosisCode     40474 non-null object
# DeductibleAmtPaid         39575 non-null float64
# DischargeDt               40474 non-null object
# DiagnosisGroupCode        40474 non-null object
# ClmDiagnosisCode_1        40474 non-null object
# ClmDiagnosisCode_2        40248 non-null object
# ClmDiagnosisCode_3        39798 non-null object
# ...

# %%
ipdata.nunique()
# Out:
# BeneID                    31289
# ClaimID                   40474
# ClaimStartDt                398
# ClaimEndDt                  365
# Provider                   2092
# InscClaimAmtReimbursed      146
# AttendingPhysician        11604
# OperatingPhysician         8287
# OtherPhysician             2877
# AdmissionDt                 398
# ClmAdmitDiagnosisCode      1928
# DeductibleAmtPaid             1
# DischargeDt                 365
# DiagnosisGroupCode          736
# ClmDiagnosisCode_1         2254
# ClmDiagnosisCode_2         2439
# ClmDiagnosisCode_3         2427
# ClmDiagnosisCode_4         2441
# ClmDiagnosisCode_5         2374
# ClmDiagnosisCode_6         2358
# ClmDiagnosisCode_7         2310
# ClmDiagnosisCode_8         2243
# ClmDiagnosisCode_9         2094
# ClmDiagnosisCode_10         952
# ClmProcedureCode_1         1117
# ClmProcedureCode_2          297
# ClmProcedureCode_3          154
# ClmProcedureCode_4           48
# ClmProcedureCode_5            6
# ...

# %%
def Dayscal(row):
    start,end=row['AdmissionDt'],row['DischargeDt']
    deltadays=relativedelta.relativedelta(pd.to_datetime( end ), pd.to_datetime( start ))
    return deltadays.days

# %%
ipdata['NoOfDays']=ipdata[['AdmissionDt','DischargeDt']].apply(Dayscal,axis=1)

# %%
ipdata[['AdmissionDt','DischargeDt','NoOfDays']].head() #Days we got of the each patient in the hospital
# Out:
#   AdmissionDt DischargeDt  NoOfDays
# 0  2009-04-12  2009-04-18         6
# 1  2009-08-31  2009-09-02         2
# 2  2009-09-17  2009-09-20         3
# 3  2009-02-14  2009-02-22         8
# 4  2009-08-13  2009-08-30        17

# %%
del ipdata['AdmissionDt']
del ipdata['DischargeDt']

# %%
ipdata.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician ClmAdmitDiagnosisCode  DeductibleAmtPaid DiagnosisGroupCode  \
# 0            NaN                  7866             1068.0                201
# ...

# %% [markdown]
# By using Claim Start date and Claim End date we are making one column as "ClaimTenure

# %%
ipdata['ClaimEndDt'] = pd.to_datetime(ipdata['ClaimEndDt'])
ipdata['ClaimStartDt'] = pd.to_datetime(ipdata['ClaimStartDt'])

# %%
ipdata['ClaimTenure'] = (ipdata['ClaimEndDt']-ipdata['ClaimStartDt']).dt.days

# %%
ipdata['ClaimTenure'].head()
# Out:
# 0     6
# 1     2
# 2     3
# 3     8
# 4    17
# Name: ClaimTenure, dtype: int64

# %%
del ipdata['ClaimEndDt']
del ipdata['ClaimStartDt']

# %% [markdown]
# Exploring about the Outpatient data
# =============================

# %%
opdata=pd.read_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Train_Outpatientdata-1542865627584.csv')

# %%
opdata.shape
# Out:
# (517737, 27)

# %%
opdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517737 entries, 0 to 517736
# Data columns (total 27 columns):
# BeneID                    517737 non-null object
# ClaimID                   517737 non-null object
# ClaimStartDt              517737 non-null object
# ClaimEndDt                517737 non-null object
# Provider                  517737 non-null object
# InscClaimAmtReimbursed    517737 non-null int64
# AttendingPhysician        516341 non-null object
# OperatingPhysician        90617 non-null object
# OtherPhysician            195046 non-null object
# ClmDiagnosisCode_1        507284 non-null object
# ClmDiagnosisCode_2        322357 non-null object
# ClmDiagnosisCode_3        203257 non-null object
# ClmDiagnosisCode_4        125596 non-null object
# ClmDiagnosisCode_5        74344 non-null object
# ClmDiagnosisCode_6        48756 non-null object
# ClmDiagnosisCode_7        32961 non-null object
# ClmDiagnosisCode_8        22912 non-null object
# ...

# %%
opdata.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# ...

# %%
opdata['ClaimEndDt'] = pd.to_datetime(opdata['ClaimEndDt'])
opdata['ClaimStartDt'] = pd.to_datetime(opdata['ClaimStartDt'])
opdata['ClaimTenure'] = (opdata['ClaimEndDt']-opdata['ClaimStartDt']).dt.days

# %%
opdata['ClaimTenure'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: ClaimTenure, dtype: int64

# %%
del opdata['ClaimStartDt']
del opdata['ClaimEndDt']

# %%
opdata.shape
# Out:
# (517737, 26)

# %%
ipdata.shape #Two columsn extra 1 Num of days in hospital 2 Diagonosis group code
# Out:
# (40474, 28)

# %%
#Got after merging
ipop_concat.DiagnosisGroupCode.count() #verified becz opdata will not have Diagnosis group code
# Out:
# 40474

# %%
ipdata.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmAdmitDiagnosisCode', 'DeductibleAmtPaid', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'NoOfDays', 'ClaimTenure'],
#       dtype='object')

# %%
opdata.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DeductibleAmtPaid', 'ClmAdmitDiagnosisCode',
#        'ClaimTenure'],
#       dtype='object')

# %%
#Combining the inpatient and outpatient data columns values whoch are not present willbe filled with Null Values
ipopdata = pd.concat([ipdata, opdata], ignore_index=True, sort=True)

# %% [markdown]
# Here we haev to different analysis for the Each ipdata opdata ipopdata.
# Each time we have to do the analysis of the each attribute.

# %%
benf.to_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Vinay_benfData',index=None)
ipdata.to_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Vinay_ipData',index=None)
opdata.to_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Vinay_opData',index=None)
ipopdata.to_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Vinay_ipopData',index=None)
#We have to merge the data ip op ipop with beneficiary data to get the complete info

# %%
ip_benf = pd.merge(left = ipdata, right = benf, on ='BeneID', how = 'inner')
op_benf = pd.merge(left = opdata, right = benf, on ='BeneID', how = 'inner')
ipop_benf = pd.merge(left = ipopdata, right = benf, on ='BeneID', how = 'inner')

# %%
print("Beneficiary shape :", benf.shape)
print("IP Data shape :", ipdata.shape)
print("OP Data shape :", opdata.shape)
print("IPOP Data shape :", ipopdata.shape)
# Out:
# Beneficiary shape : (138556, 25)
# IP Data shape : (40474, 28)
# OP Data shape : (517737, 26)
# IPOP Data shape : (558211, 28)

# %%
print("Beneficiary IP shape :", ip_benf.shape)
print("Beneficiary OP shape :", op_benf.shape)
print("Beneficiary IP_OP shape :", ipop_benf.shape)
# Out:
# Beneficiary IP shape : (40474, 52)
# Beneficiary OP shape : (517737, 50)
# Beneficiary IP_OP shape : (558211, 52)

# %% [markdown]
# Final Data After merging and cleaning

# %%
ip_benf = pd.merge(left = ip_benf, right = df, on ='Provider', how = 'inner')
op_benf = pd.merge(left = op_benf, right = df, on ='Provider', how = 'inner')
ipop_benf = pd.merge(left = ipop_benf, right = df, on ='Provider', how = 'inner')

# %%
ip_benf.PotentialFraud.value_counts()
# Out:
# Yes    23402
# No     17072
# Name: PotentialFraud, dtype: int64

# %%
ip_benf.to_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Vinay_ipData',index=None)
op_benf.to_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Vinay_opData',index=None)
ipop_benf.to_csv('C:/Users/bkumar66/Desktop/ML/Ph_D_DATA/Vinay/Vinay_ipopData',index=None)

# %%
#ip_benfi ,traindata (Provider)
train_ip_final = pd.merge(left = ip_benfi,right = traindata, on ='Provider', how= 'inner')
#ip_benfi ,traindata (Provider)
train_op_final = pd.merge(left = op_benfi,right = traindata, on ='Provider', how= 'inner') #Have to Do this

# %% [markdown]
# EDA
# ====

# %%
sns.countplot(y='PotentialFraud', data=final_data)
